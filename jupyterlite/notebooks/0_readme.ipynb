# %% [markdown]
# # Important Notes
#
# ## Local Execution
# All code is processed and executed locally on your PC. Nothing is sent to the cloud.
#
# ## File Storage
# Files are saved in the browser cache. While files are generally retained, they may be lost in certain situations. Therefore, it is recommended to download any important files you create.

# %% [markdown]
# ## Minimal usage sample

# %%
# %pip install pitct

# %%
import pitct

pitct.__version__
